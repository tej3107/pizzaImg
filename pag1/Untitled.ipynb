# %%
# !pip install pillow

# %%
import numpy as np

# %%
from PIL import Image

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is AA92-1360
#
#  Directory of C:\Users\TEJ NARAYAN SINGH\OneDrive\Desktop\Pizza\pizza2\pag1
#
# 22-02-2022  18:53    <DIR>          .
# 22-02-2022  18:47    <DIR>          ..
# 22-02-2022  18:53    <DIR>          .ipynb_checkpoints
# 22-02-2022  18:48           659,739 1.jpeg
# 22-02-2022  18:51    <DIR>          1000X400
# 22-02-2022  18:48           258,603 2.jpeg
# 22-02-2022  18:49           318,984 3.jpeg
# 22-02-2022  18:49           241,769 4.jpeg
# 22-02-2022  18:50           217,506 5.jpeg
# 22-02-2022  18:53           942,878 Untitled.ipynb
#                6 File(s)      2,639,479 bytes
#                4 Dir(s)  147,192,328,192 bytes free

# %%
for i in range(1,6):
    img = Image.open(str(i)+'.jpeg')
    img = img.resize((1000,400))
#     img.save('./1000X400/1.jpeg')
    img.show()

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=1000x400 at 0x23CCBDC3DC0>
